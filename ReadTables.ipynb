# %%
# import statements
import os
import shutil
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
import SPIutils as spi
from SPIworkflow.__init__ import *
from SPIworkflow.constants import *

# %%
df = pd.read_csv("./INPUT/SPI-sources_planets_MASTER.csv")

# %%
df2 = df[["star_name", "d_star(pc)", "mass_star(m_sun)", "radius_star(r_sun)", "p_rot(days)", "bfield_star(gauss)",
          "planet_name", "p_orb(days)", "a(au)", "radius_planet(r_earth)", "mass_planet(m_earth)","ra(deg)", "dec(deg)"]]
mask_d = df2['d_star(pc)'] < 10.0
mask_porb = df2['p_orb(days)'] < 10.0
#mask_Prot = df2['p_rot(days)'] < 20.0
mask_Bfield = df2['bfield_star(gauss)'] > 100.0
mask_dec    = df2['dec(deg)'] > -54.0
#data = df2[mask_d & mask_Prot & mask_Bfield & mask_dec]
data = df2[mask_d & mask_porb & mask_Bfield & mask_dec]
data.reset_index(inplace=True)
len(data[:])
data[:]
# Out:
#     index               star_name  d_star(pc)  mass_star(m_sun)  \
# 0       0                 CD Cet     8.609290              0.18
# 1       2              HD 285968     9.473043              0.51
# 2       9             LP 656-038     5.375676              0.18
# 3      13          Luyten's Star     3.786059              0.30
# 4      22                 GJ 357     9.444387              0.37
# 5      23                 GJ 357     9.444387              0.37
# 6      30             BD+01 2447     7.032918              0.45
# 7      32                 CN Leo     2.408597              0.14
# 8      40                 FI Vir     3.374875              0.20
# 9      42               Wolf 437     8.076142              0.35
# 10     47                 HO Lib     6.299244              0.34
# 11     49                 HO Lib     6.299244              0.34
# 12     52              V2306 Oph     4.306456              0.33
# 13     64                 AU Mic     9.724836              0.50
# 14     77                 IL Aqr     4.675805              0.37
#
#     radius_star(r_sun) p_rot(days)  bfield_star(gauss)  planet_name  \
# 0                 0.21       126.2                 253     CD Cet b
# 1                 0.51        40.7                 350     GJ 176 b
# 2                 0.21        88.5                1135    GJ 3323 b
# 3                 0.30        93.5                 219     GJ 273 c
# 4                 0.36        74.3                 129     GJ 357 b
# 5                 0.36        74.3                 129     GJ 357 c
# 6                 0.45        32.7                 273     GJ 393 b
# 7                 0.15         2.7                3014   Wolf 359 c
# 8                 0.22         163                 279   Ross 128 b
# 9                 0.36        49.3                 118     GJ 486 b
# 10                0.34       132.5                 156     GJ 581 b
# 11                0.34       132.5                 156     GJ 581 e
# 12                0.34         119                 112  Wolf 1061 b
# 13                0.75         4.9                3007     AU Mic b
# 14                0.38          81                 197     GJ 876 d
#
#     p_orb(days)    a(au)  radius_planet(r_earth)  mass_planet(m_earth)  \
# 0      2.290700  0.01850                1.439236              3.953432
# 1      8.774800  0.06600                1.718340              7.945000
# 2      5.363600  0.03282                1.209451              2.033920
# 3      4.723220  0.03600                1.050283              1.188572
# 4      3.930860  0.03300                1.166969              2.086675
# 5      9.124600  0.06070                1.413455              3.686480
# 6      7.026790  0.05402                1.156769              1.716120
# 7      2.686870  0.01800                1.425785              3.813600
# 8      9.865800  0.04960                1.097361              1.398320
# 9      1.467119  0.01734                1.305064              2.818886
# 10     5.368000  0.04100                2.425628             15.190840
# 11     3.153000  0.02900                1.147802              1.652560
# 12     4.886900  0.03750                1.191517              1.906800
# 13     8.462991  0.06450                4.380477             16.843400
# 14     1.938000  0.02100                1.658932              6.909290
#
#        ra(deg)   dec(deg)
# 0    48.345490   4.774818
# 1    70.732397  18.958165
# 2    75.489275  -6.946214
# 3   111.852079   5.225789
# 4   144.006822 -21.660800
# 5   144.006822 -21.660800
# 6   157.231464   0.841001
# 7   164.120504   7.014723
# 8   176.934987   0.804557
# 9   191.985937   9.751398
# 10  229.861780  -7.722275
# 11  229.861780  -7.722275
# 12  247.575243 -12.662590
# 13  311.289718 -31.340900
# 14  343.319718 -14.263695
